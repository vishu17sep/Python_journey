# %% [markdown]
# # Blue Mission Overview
#
# Looks like the email reply had two links:
#
# https://drive.google.com/file/d/15YyLqIuGlsCLr4ioKUeHRw8H2QjBNOz2/view
#
# https://drive.google.com/file/d/128MRLNuytoW7dVm6B7AF_cDVMeACyTFk/view
#
# See if you can figure out how to use these images to figure out the next step.
#
# Best of luck!

# %%
from PIL import Image

# %%
cover = Image.open("Blue_Mission_Files/cover_image.png")
image_l = Image.open("Blue_Mission_Files/image_link.png")
cover.putalpha(128)
print(cover.size)
image_l.size
image_l=image_l.resize((1093, 693))
# Out:
# (1093, 693)

# %%
image_l.paste(cover,(0,0),mask=cover)

# %%
image_l
# Out:
# <PIL.Image.Image image mode=RGBA size=1093x693 at 0x2E94018D6D8>
